# %% [markdown]
# # Analysis of Covid-19 NYC data
# Analyzing hospitalization and mortality rates
#
# Most of the work is figuring out which numbers to use, because mortality counts and hospitalizations come some time after infections.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
from matplotlib import pyplot as plt
import matplotlib.ticker as mticker
import utilities as u

plt.rcParams['axes.grid'] = True
plt.rcParams['axes.grid.which'] = "both"
plt.rcParams['xtick.minor.visible'] = True
plt.rcParams['ytick.minor.visible'] = True
# plt.rcParams['figure.autolayout'] = True

def pltdflt(figsize=(12, 10)):
    fig, ax = plt.subplots(figsize=figsize)
    plt.grid(True, which="minor", linestyle="--")
    plt.grid(True, which="major", color="0.5")
    return fig, ax

# %%
dat = u.load_data()
dat = u.add_averages(dat)

# %%
dat.head()
# Out:
#                   NEW_COVID_CASE_COUNT  PROBABLE_CASE_COUNT  \
# DATE_OF_INTEREST
# 2020-02-29                           1                    0
# 2020-03-01                           0                    0
# 2020-03-02                           0                    0
# 2020-03-03                           1                    0
# 2020-03-04                           5                    0
#
#                   HOSPITALIZED_COUNT  DEATH_COUNT  PROBABLE_DEATH_COUNT  \
# DATE_OF_INTEREST
# 2020-02-29                         1            0                     0
# 2020-03-01                         1            0                     0
# 2020-03-02                         2            0                     0
# 2020-03-03                         7            0                     0
# 2020-03-04                         2            0                     0
#
#                   CASE_COUNT_7DAY_AVG  ALL_CASE_COUNT_7DAY_AVG  \
# DATE_OF_INTEREST
# 2020-02-29                          0                        0
# 2020-03-01                          0                        0
# 2020-03-02                          0                        0
# 2020-03-03                          0                        0
# 2020-03-04                          0                        0
#
#                   HOSP_COUNT_7DAY_AVG  DEATH_COUNT_7DAY_AVG  \
# DATE_OF_INTEREST
# 2020-02-29                          0                     0
# 2020-03-01                          0                     0
# 2020-03-02                          0                     0
# 2020-03-03                          0                     0
# 2020-03-04                          0                     0
#
#                   ALL_DEATH_COUNT_7DAY_AVG  ...  SI_CASE_COUNT_7DAY_AVG  \
# DATE_OF_INTEREST                            ...
# 2020-02-29                               0  ...                       0
# 2020-03-01                               0  ...                       0
# 2020-03-02                               0  ...                       0
# 2020-03-03                               0  ...                       0
# 2020-03-04                               0  ...                       0
#
#                   SI_PROBABLE_CASE_COUNT_7DAY_AVG  SI_ALL_CASE_COUNT_7DAY_AVG  \
# DATE_OF_INTEREST
# 2020-02-29                                      0                           0
# 2020-03-01                                      0                           0
# 2020-03-02                                      0                           0
# 2020-03-03                                      0                           0
# 2020-03-04                                      0                           0
#
#                   SI_HOSPITALIZED_COUNT_7DAY_AVG  SI_DEATH_COUNT_7DAY_AVG  \
# DATE_OF_INTEREST
# 2020-02-29                                     0                        0
# 2020-03-01                                     0                        0
# 2020-03-02                                     0                        0
# 2020-03-03                                     0                        0
# 2020-03-04                                     0                        0
#
#                   SI_ALL_DEATH_COUNT_7DAY_AVG  INCOMPLETE  \
# DATE_OF_INTEREST
# 2020-02-29                                  0           0
# 2020-03-01                                  0           0
# 2020-03-02                                  0           0
# 2020-03-03                                  0           0
# 2020-03-04                                  0           0
#
#                   Cases/day, 7 day avg  Hospitalized/day, 7 day avg  \
# DATE_OF_INTEREST
# 2020-02-29                    1.000000                     1.000000
# 2020-03-01                    0.500000                     1.000000
# 2020-03-02                    0.333333                     1.333333
# 2020-03-03                    0.500000                     2.750000
# 2020-03-04                    1.400000                     2.600000
#
#                   Deaths/day, 7 day avg
# DATE_OF_INTEREST
# 2020-02-29                          0.0
# 2020-03-01                          0.0
# 2020-03-02                          0.0
# 2020-03-03                          0.0
# 2020-03-04                          0.0
#
# [5 rows x 69 columns]

# %% [markdown]
# # Peak analysis

# %% [markdown]
# ## First wave
# Oddly, cases/day peaked after hospitalized/day.  Cases/day peak is 4 days *after* hospitalized/day peak.  Deaths/day peak is 3 days later.

# %%
start = "2020-04-01"
end = "2020-04-30"
period = dat[(dat.index >= start) & (dat.index < end)]

u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalized/day, 7 day avg",
                     "Deaths/day, 7 day avg"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %% [markdown]
# ## Second wave
# Delays are different.  Peak hospitalized/day is 10 days after peak cases/day.  Peak deaths/day is ~Feb 16, vs Jan 8, about 39 days.

# %%
start = "2021-01-01"
end = "2021-03-01"
period = dat[(dat.index >= start) & (dat.index < end)]

u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalized/day, 7 day avg",
                     "Deaths/day, 7 day avg"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %% [markdown]
# # Rates
# Looking at rates per case, but with shifts to account for delays

# %%
dat["Hospitalizations per infection"] = dat["Hospitalized/day, 7 day avg"]/dat["Cases/day, 7 day avg"]
dat["Deaths per infection"] = dat["Deaths/day, 7 day avg"]/dat["Cases/day, 7 day avg"]

# %%
u.plot_multi(dat[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %%
start = "2020/03/15"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %% [markdown]
# ## 7 day shift

# %%
shift = 7
dat["Hospitalizations per infection"] = dat["Hospitalized/day, 7 day avg"].shift(shift)/dat["Cases/day, 7 day avg"]
dat["Deaths per infection"] = dat["Deaths/day, 7 day avg"].shift(shift)/dat["Cases/day, 7 day avg"]

# %%
start = "2020/03/15"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %% [markdown]
# ## 14 day shift

# %%
shift = 14
dat["Hospitalizations per infection"] = dat["Hospitalized/day, 7 day avg"].shift(shift)/dat["Cases/day, 7 day avg"]
dat["Deaths per infection"] = dat["Deaths/day, 7 day avg"].shift(shift)/dat["Cases/day, 7 day avg"]

# %%
start = "2020/03/15"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %% [markdown]
# ## Lots of shifts

# %%
"""
start = "2020/03/15"

statresults = pd.DataFrame(columns=["shift", "h/i mean", "h/i std", "d/i mean", "d/i std"])

for shift in range(-30, 30):
    dat["Hospitalizations per infection"] = dat["Hospitalized/day, 7 day avg"].shift(shift)/dat["Cases/day, 7 day avg"]
    dat["Deaths per infection"] = dat["Deaths/day, 7 day avg"].shift(shift)/dat["Cases/day, 7 day avg"]
    period = dat[dat.index > start]
    u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
    print(f"Rates shifted by {shift} days")
    stats = period[["Cases/day, 7 day avg",
                    "Hospitalizations per infection",
                    "Deaths per infection"]].describe()
    display(stats)
    plt.title(f"Rates shifted by {shift} days")
    plt.show()
"""
# Out:
# '\nstart = "2020/03/15"\n\nstatresults = pd.DataFrame(columns=["shift", "h/i mean", "h/i std", "d/i mean", "d/i std"])\n\nfor shift in range(-30, 30):\n    dat["Hospitalizations per infection"] = dat["Hospitalized/day, 7 day avg"].shift(shift)/dat["Cases/day, 7 day avg"]\n    dat["Deaths per infection"] = dat["Deaths/day, 7 day avg"].shift(shift)/dat["Cases/day, 7 day avg"]\n    period = dat[dat.index > start]\n    u.plot_multi(period[["Cases/day, 7 day avg",\n                     "Hospitalizations per infection",\n                     "Deaths per infection"]], figsize=(12, 5))\n    print(f"Rates shifted by {shift} days")\n    stats = period[["Cases/day, 7 day avg",\n                    "Hospitalizations per infection",\n                    "Deaths per infection"]].describe()\n    display(stats)\n    plt.title(f"Rates shifted by {shift} days")\n    plt.show()\n'

# %% [markdown]
# # Shift analysis
# Find which shifts give the min std.  That should be the right shift.

# %%
ratenames = ["Hospitalized per infection", "Deaths per infection"]

# %% [markdown]
# ## On an 1 week avg basis

# %%
wks = 1

# %%
columns = [f"Cases/day, {wks} wk avg", f"Hospitalized/day, {wks} wk avg", f"Deaths/day, {wks} wk avg"]
days = wks*7

dat = u.add_averages(dat,
                     in_cols = u.count_cols,
                     out_cols = columns,
                     window_size = f"{days}D")

denom = columns[0]
columns = columns[1:]

# %%
start = "2020/03/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/06/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/09/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/04/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/05/15"
shifts = [28, 26]

for numerator, col in zip(columns, ["H/I, {shift}", "D/I, {shift}"]):
    cols = []
    for shift in shifts:
        colname = col.format(shift=shift)
        cols.append(colname)
        dat[colname] = dat[numerator]/dat[denom].shift(shift)
    period = dat[dat.index > start]
    period[cols].plot()
    plt.show()

# %%
start = "2020/05/15"
shifts = [5, 7]

for numerator, col in zip(columns, ["H/I, {shift}", "D/I, {shift}"]):
    cols = []
    for shift in shifts:
        colname = col.format(shift=shift)
        cols.append(colname)
        dat[colname] = dat[numerator]/dat[denom].shift(shift)
    period = dat[dat.index > start]
    period[cols].plot()
    plt.show()

# %%
shifts = [7, 28]

for shift, name, numerator in zip(shifts, ratenames, columns):
    dat[name] = dat[numerator]/dat[denom].shift(shift)

# %%
start = "2020/01/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %%
start = "2020/06/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %%
start = "2021/04/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %% [markdown]
# ## On an 4 week avg basis

# %%
wks = 4

# %%
columns = [f"Cases/day, {wks} wk avg", f"Hospitalized/day, {wks} wk avg", f"Deaths/day, {wks} wk avg"]
days = wks*7

dat = u.add_averages(dat,
                     in_cols = u.count_cols,
                     out_cols = columns,
                     window_size = f"{days}D")

denom = columns[0]
columns = columns[1:]

# %%
start = "2020/03/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/06/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/09/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/04/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/05/15"
shifts = [28, 26]

for numerator, col in zip(columns, ["H/I, {shift}", "D/I, {shift}"]):
    cols = []
    for shift in shifts:
        colname = col.format(shift=shift)
        cols.append(colname)
        dat[colname] = dat[numerator]/dat[denom].shift(shift)
    period = dat[dat.index > start]
    period[cols].plot()
    plt.show()

# %%
start = "2020/05/15"
shifts = [5, 7]

for numerator, col in zip(columns, ["H/I, {shift}", "D/I, {shift}"]):
    cols = []
    for shift in shifts:
        colname = col.format(shift=shift)
        cols.append(colname)
        dat[colname] = dat[numerator]/dat[denom].shift(shift)
    period = dat[dat.index > start]
    period[cols].plot()
    plt.show()

# %%
shifts = [7, 28]

for shift, name, numerator in zip(shifts, ratenames, columns):
    dat[name] = dat[numerator]/dat[denom].shift(shift)

# %%
start = "2020/01/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %%
start = "2020/06/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %%
start = "2021/04/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %% [markdown]
# ## On a 12 week avg basis

# %%
wks = 12

# %%
columns = [f"Cases/day, {wks} wk avg", f"Hospitalized/day, {wks} wk avg", f"Deaths/day, {wks} wk avg"]
days = wks*7

dat = u.add_averages(dat,
                     in_cols = u.count_cols,
                     out_cols = columns,
                     window_size = f"{days}D")

denom = columns[0]
columns = columns[1:]

# %%
start = "2020/03/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/06/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/09/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/04/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/05/15"
shifts = [28, 26]

for numerator, col in zip(columns, ["H/I, {shift}", "D/I, {shift}"]):
    cols = []
    for shift in shifts:
        colname = col.format(shift=shift)
        cols.append(colname)
        dat[colname] = dat[numerator]/dat[denom].shift(shift)
    period = dat[dat.index > start]
    period[cols].plot()
    plt.show()

# %%
start = "2020/05/15"
shifts = [5, 7]

for numerator, col in zip(columns, ["H/I, {shift}", "D/I, {shift}"]):
    cols = []
    for shift in shifts:
        colname = col.format(shift=shift)
        cols.append(colname)
        dat[colname] = dat[numerator]/dat[denom].shift(shift)
    period = dat[dat.index > start]
    period[cols].plot()
    plt.show()

# %%
shifts = [7, 28]

for shift, name, numerator in zip(shifts, ratenames, columns):
    dat[name] = dat[numerator]/dat[denom].shift(shift)

# %%
start = "2020/01/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %%
start = "2020/06/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %%
start = "2021/04/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %% [markdown]
# ## On an 16 week avg basis

# %%
wks = 16

# %%
columns = [f"Cases/day, {wks} wk avg", f"Hospitalized/day, {wks} wk avg", f"Deaths/day, {wks} wk avg"]
days = wks*7

dat = u.add_averages(dat,
                     in_cols = u.count_cols,
                     out_cols = columns,
                     window_size = f"{days}D")

denom = columns[0]
columns = columns[1:]

# %%
start = "2020/03/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/06/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/09/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/04/15"
stddevs = u.calc_rate_std(dat[dat.index > start], -45, 45, columns, denom)
stddevs.plot()
# Out:
# <AxesSubplot:xlabel='Shift'>

# %%
start = "2020/05/15"
shifts = [28, 26]

for numerator, col in zip(columns, ["H/I, {shift}", "D/I, {shift}"]):
    cols = []
    for shift in shifts:
        colname = col.format(shift=shift)
        cols.append(colname)
        dat[colname] = dat[numerator]/dat[denom].shift(shift)
    period = dat[dat.index > start]
    period[cols].plot()
    plt.show()

# %%
start = "2020/05/15"
shifts = [5, 7]

for numerator, col in zip(columns, ["H/I, {shift}", "D/I, {shift}"]):
    cols = []
    for shift in shifts:
        colname = col.format(shift=shift)
        cols.append(colname)
        dat[colname] = dat[numerator]/dat[denom].shift(shift)
    period = dat[dat.index > start]
    period[cols].plot()
    plt.show()

# %%
shifts = [7, 28]

for shift, name, numerator in zip(shifts, ratenames, columns):
    dat[name] = dat[numerator]/dat[denom].shift(shift)

# %%
start = "2020/01/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %%
start = "2020/06/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %%
start = "2021/04/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Hospitalizations per infection",
                     "Deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %% [markdown]
# # Long term rate
# Looking at overall rates per cases.
#
# Since we're dividing totals by totals, we can do without shifts

# %%
dat = u.add_aggregates(dat)

# %%
shift = 0
dat["Total hospitalizations per infection"] = dat["Total hospitalized"]/dat["Total cases"].shift(shift)

shift = 0
dat["Total deaths per infection"] = dat["Total deaths"]/dat["Total cases"].shift(shift)

# %%
start = "2019/01/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Total hospitalizations per infection",
                     "Total deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %%
start = "2020/04/15"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Total hospitalizations per infection",
                     "Total deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %%
start = "2020/07/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Total hospitalizations per infection",
                     "Total deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>

# %%
start = "2021/03/01"
period = dat[dat.index > start]
u.plot_multi(period[["Cases/day, 7 day avg",
                     "Total hospitalizations per infection",
                     "Total deaths per infection"]], figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='DATE_OF_INTEREST', ylabel='Cases/day, 7 day avg'>
